# %%
# %pylab inline
import datetime
import pandas as pd
import numpy as np
import os
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import itertools
import string
import seaborn as sns

# %%
# Figure 1 B

data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/qPCR data/200312.3_qPCR_results_GAHACR.xlsx')
data=data[(data['Primers']=='GA20ox1-3')]
data['replicate'] = [1,2,3,1,2,3]*2

fig = sns.FacetGrid(data=data,size=3,sharex=False,sharey=False,ylim=(0,0.01))
fig = fig.map(sns.boxplot,'Guide','Normalized Cp',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Normalized Cp','replicate',palette='YlOrRd').add_legend()
print(stats.ttest_ind(a=data[data['Guide']=='On target']['Normalized Cp'],b=data[data['Guide']=='Off target']['Normalized Cp'],equal_var=False))
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/191021_PHD6_TRV_Targetting_GA20ox_qPCR_GA20ox1-3.svg')

# Figure 1 C

data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/Data/191125_PHD6_ViN_Luc_data.xlsx')

# data = data[data['Leaf Number']<6]

fig = sns.FacetGrid(data=data,sharex=False,sharey=False)
fig = fig.map(sns.boxplot,'Guide','Luminescence',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Luminescence','Replicate',palette='YlOrRd').add_legend()
print(stats.ttest_ind(a=data[data['Guide']=='On target']['Luminescence'],b=data[data['Guide']=='Off target']['Luminescence'],equal_var=False))
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/191125_PHD6_ViN_Luc_data_all_leaves.svg')

# Figure 1 D

data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/Data/191125_PHD6_leaf_size_phenotyping.xlsx')

data = data[data['Leaf number']<18]

fig = sns.FacetGrid(data=data,col='Leaf number',sharex=False,sharey=False)
fig = fig.map(sns.boxplot,'Guide','Area',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Area',palette='YlOrRd').add_legend()

fig = sns.FacetGrid(data=data,sharex=False,sharey=False,aspect=2.5)
fig = fig.map(sns.boxplot,'Leaf number','Area','Guide',palette='Greys').add_legend()
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/191125_PHD6_leaf_size_phenotyping_seperated_by_leaf.svg')

fig = sns.FacetGrid(data=data,sharex=False,sharey=False)
fig = fig.map(sns.boxplot,'Guide','Area',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Area','Leaf number',palette='YlOrRd').add_legend()
print('All leaves till 17')
print(stats.ttest_ind(a=data[data['Guide']=='On target']['Area'],b=data[data['Guide']=='Off target']['Area'],equal_var=False))
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/191125_PHD6_leaf_size_phenotyping_all_leaves.svg')

data = data[data['Leaf number']>7]
data = data[data['Leaf number']<12]
fig = sns.FacetGrid(data=data,sharex=False,sharey=False,ylim=(0,25000))
fig = fig.map(sns.boxplot,'Guide','Area',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Area','Leaf number',palette='YlOrRd').add_legend()
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/191125_PHD6_leaf_size_phenotyping_leaves_8-11.svg')

print('leaves 8-11')
print(stats.ttest_ind(a=data[data['Guide']=='On target']['Area'],b=data[data['Guide']=='Off target']['Area'],equal_var=False))


# Figure 1 Supplementary Figure 1

data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/qPCR data/200312.3_qPCR_results_GAHACR.xlsx')
data=data[(data['Primers']=='GA20ox1-2')]
data['replicate'] = [1,2,3,1,2,3]*2

fig = sns.FacetGrid(data=data,size=3,sharex=False,sharey=False,ylim=(0,0.13))
fig = fig.map(sns.boxplot,'Guide','Normalized Cp',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Normalized Cp','replicate',palette='YlOrRd')
print(stats.ttest_ind(a=data[data['Guide']=='On target']['Normalized Cp'],b=data[data['Guide']=='Off target']['Normalized Cp'],equal_var=False))
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/191021_PHD6_TRV_Targetting_GA20ox_qPCR_GA20ox1-2.svg')


data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/qPCR data/200312.3_qPCR_results_GAHACR.xlsx')
data=data[(data['Primers']=='GA20ox1-1')]
data['replicate'] = [1,2,3,1,2,3]*2

fig = sns.FacetGrid(data=data,size=3,sharex=False,sharey=False,ylim=(0,0.35))
fig = fig.map(sns.boxplot,'Guide','Normalized Cp',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Normalized Cp','replicate',palette='YlOrRd')
print(stats.ttest_ind(a=data[data['Guide']=='On target']['Normalized Cp'],b=data[data['Guide']=='Off target']['Normalized Cp'],equal_var=False))
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/191021_PHD6_TRV_Targetting_GA20ox_qPCR_GA20ox1-1.svg')


data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/qPCR data/191019_qPCR_results.xlsx')

data=data[data['Primers']=='GA20ox1D-1']
fig = sns.FacetGrid(data=data,size=3,sharex=False,sharey=False,ylim=(0,0.0012))
fig = fig.map(sns.boxplot,'Guide','Normalized Cp',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Normalized Cp',palette='YlOrRd').add_legend()
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/191021_PHD6_TRV_Targetting_GA20ox_qPCR_GA20ox1D-1.svg')


data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/qPCR data/191019_qPCR_results.xlsx')

data=data[data['Primers']=='GA20ox1D-2']
fig = sns.FacetGrid(data=data,size=3,sharex=False,sharey=False,ylim=(0,0.00004))
fig = fig.map(sns.boxplot,'Guide','Normalized Cp',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Normalized Cp',palette='YlOrRd').add_legend()
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/191021_PHD6_TRV_Targetting_GA20ox_qPCR_GA20ox1D-2.svg')

# Figure 1 supplementary figure 3
data = pd.io.excel.read_excel('/Users/clab/Google Drive/Plant viral vectors/qPCR Data/201104_qPCR_results_Dose_response.xlsx')
fig = sns.FacetGrid(data=data,row='Guide',sharey=False,aspect=1.1)
fig = fig.map(sns.barplot,'Treatment','Normalized Cp',palette='Greens')


# Figure 2 B

data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/qPCR data/200322_qPCR_results.xlsx')
data=data[data['Primers']=='GID1a']

fig = sns.FacetGrid(data=data,row='Primers',sharex=False,sharey=False,ylim=(0,0.8))
fig = fig.map(sns.boxplot,'Guide','Normalized Cp',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Normalized Cp','Replicate',palette='YlOrRd').add_legend()
print(stats.ttest_ind(a=data[data['Guide']=='On target']['Normalized Cp'],b=data[data['Guide']=='Off target']['Normalized Cp'],equal_var=False))
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/200128_Arabidopsis_ViN1_GID1a_qPCR.svg')

data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/qPCR data/200322_qPCR_results.xlsx')
data=data[data['Primers']=='GID1b']

fig = sns.FacetGrid(data=data,row='Primers',sharex=False,sharey=False,ylim=(0,0.6))
fig = fig.map(sns.boxplot,'Guide','Normalized Cp',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Normalized Cp','Replicate',palette='YlOrRd').add_legend()
print(stats.ttest_ind(a=data[data['Guide']=='On target']['Normalized Cp'],b=data[data['Guide']=='Off target']['Normalized Cp'],equal_var=False))
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/200128_Arabidopsis_ViN1_GID1b_qPCR.svg')

data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/qPCR data/200128_qPCR_results.xlsx')

data=data[data['Primers']=='GID1c']
data=data[data['Target']!='LBD16 repression, PAP1 activation']

fig = sns.FacetGrid(data=data,row='Primers',sharex=False,sharey=False,ylim=(0,0.65))
fig = fig.map(sns.boxplot,'Target','Normalized Cp',palette='Greys')
fig = fig.map(sns.swarmplot,'Target','Normalized Cp','Replicate',palette='YlOrRd').add_legend()
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/200128_Arabidopsis_ViN1_GID1c_qPCR.svg')
print(stats.ttest_ind(a=data[data['Target']=='GID repression, PAP1 activation']['Normalized Cp'],b=data[data['Target']=='Off target']['Normalized Cp'],equal_var=False))

data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/Data/200312_HL3_GID_PAP1_ViN_Phenotyping_leaf_size.xlsx')

fig = sns.FacetGrid(data=data,sharex=False,sharey=False)
fig = fig.map(sns.boxplot,'Guide','Area',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Area','Replicate',palette='YlOrRd',size=4).add_legend()
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/200312_HL3_GID_PAP1_ViN_Phenotyping_leaf_size_all_leaves.svg')

# Figure 2 C

print(stats.ttest_ind(a=data[data['Guide']=='On target']['Normalized Cp'],b=data[data['Guide']=='Off target']['Normalized Cp'],equal_var=False))


data2 = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/qPCR data/200322_qPCR_results.xlsx')
data2=data2[data2['Primers']=='PAP1']
data2=data2[data2['Technical replicate']==1]


fig = sns.FacetGrid(data=data2,row='Primers',sharex=False,sharey=False,ylim=(0,2.5))
fig = fig.map(sns.boxplot,'Guide','Normalized Cp',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Normalized Cp','Replicate',palette='YlOrRd').add_legend()
print(stats.ttest_ind(a=data2[data2['Guide']=='On target']['Normalized Cp'],b=data2[data2['Guide']=='Off target']['Normalized Cp'],equal_var=False))
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/200128_Arabidopsis_ViN1_PAP1_qPCR.svg')



data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/Data/200105_Arabidopsis_HACKER_ViN_Phenotyping_data_Leaf_color_B_v_G_For_plotting.xlsx')

data=data[data['Guide']!='On target - 8']
fig = sns.FacetGrid(data=data,sharex=False,sharey=False,ylim=(0,0.52))
fig = fig.map(sns.boxplot,'Guide','Mean Blue/Green signal (AU)',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Mean Blue/Green signal (AU)','Replicate',palette='YlOrRd')
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/200105_Arabidopsis_HACKER_ViN_PAP1_treatment_7_phenotyping_BvG.svg')
print(stats.ttest_ind(a=data[data['Guide']=='On target']['Mean Blue/Green signal (AU)'],b=data[data['Guide']=='Off target']['Mean Blue/Green signal (AU)'],equal_var=False))


# Figure 2 Supplementary Figure 1 D
data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/Data/200105_Arabidopsis_HACKER_ViN_Phenotyping_data_Leaf_color_B_v_G_For_plotting.xlsx')

data=data[data['Guide']!='On target']
fig = sns.FacetGrid(data=data,sharex=False,sharey=False,ylim=(0,0.55))
fig = fig.map(sns.boxplot,'Guide','Mean Blue/Green signal (AU)',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Mean Blue/Green signal (AU)','Replicate',palette='YlOrRd')
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/200105_Arabidopsis_HACKER_ViN_PAP1_treatment_8_phenotyping_BvG.svg')
print(stats.ttest_ind(a=data[data['Guide']=='On target - 8']['Mean Blue/Green signal (AU)'],b=data[data['Guide']=='Off target']['Mean Blue/Green signal (AU)'],equal_var=False))

#Figure 2 Supplementary figure 2

data= pd.read_excel('/Users/clab/Google Drive/Plant viral vectors/Data/201027_Arabidopsis_Vin1_phenotyping_HL3.xlsx')
fig = sns.FacetGrid(data=data,sharex=False,sharey=False,ylim=(0,0.70))
fig = fig.map(sns.boxplot,'Guide','Actual A536',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Actual A536','Replicate',palette='YlOrRd')
fig.savefig('/Users/clab/Google Drive/Plant viral vectors/Figures/201027_ViN1_HL3_Anthocyanin_quant.svg')
print(stats.ttest_ind(a=data[(data['Guide']=='Ontarget')&(data['Plant']=='HL3 T1-4')]['Actual A536'],b=data[(data['Guide']=='Off target')&(data['Plant']=='HL3 T1-4')]['Actual A536'],equal_var=False))

data= pd.read_excel('/Users/clab/Google Drive/Plant viral vectors/Data/201027_Arabidopsis_Vin1_phenotyping_HL20.xlsx')
fig = sns.FacetGrid(data=data,sharex=False,sharey=False,ylim=(0,0.85))
fig = fig.map(sns.boxplot,'Guide','Actual A536',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Actual A536','Replicate',palette='YlOrRd')
fig.savefig('/Users/clab/Google Drive/Plant viral vectors/Figures/201027_ViN1_HL20_Anthocyanin_quant.svg')

print(stats.ttest_ind(a=data[(data['Guide']=='Ontarget')&(data['Plant']=='HL20 T1-3')]['Actual A536'],b=data[(data['Guide']=='Off target')&(data['Plant']=='HL20 T1-3')]['Actual A536'],equal_var=False))


# Figure 3 C
data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/qPCR data/191022_qPCR_results.xlsx')

data2 = data[data['FT']=='No']
print(stats.ttest_ind(a=data2[data2['Guide']=='On target']['Normalized Cp'],b=data2[data2['Guide']=='Off target']['Normalized Cp'],equal_var=False))
fig = sns.FacetGrid(data=data2,col='FT',sharex=False,sharey=False,ylim=(0,2))
fig = fig.map(sns.boxplot,'Guide','Normalized Cp',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Normalized Cp',palette='YlOrRd')
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/191022_Benthe_ViN2_PDS_FTvsNoFT_qPCR_boxplot_No_FT.svg')


data2 = data[data['FT']=='Yes']
print(stats.ttest_ind(a=data2[data2['Guide']=='On target']['Normalized Cp'],b=data2[data2['Guide']=='Off target']['Normalized Cp'],equal_var=False))
fig = sns.FacetGrid(data=data2,col='FT',sharex=False,sharey=False,ylim=(0,1))
fig = fig.map(sns.boxplot,'Guide','Normalized Cp',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Normalized Cp',palette='YlOrRd')
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/191022_Benthe_ViN2_PDS_FTvsNoFT_qPCR_boxplot_Yes_FT.svg')

# Figure 3 Supplementary Figure 1
data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/qPCR data/191022_qPCR_results.xlsx')
data = data[(data['Primers']=='PCP')]
data = data[(data['Effector']!='None')]


fig = sns.FacetGrid(data=data,sharex=False,sharey=True)
fig = fig.map(sns.boxplot,'FT','Normalized Cp',palette='Greys')
fig = fig.map(sns.swarmplot,'FT','Normalized Cp',palette='YlOrRd')
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/191022_qPCR_results_Viral_levels_of_FT_vs_no_FT.svg')

print(stats.ttest_ind(a=data[data['FT']=='Yes']['Normalized Cp'],b=data[data['FT']=='No']['Normalized Cp'],equal_var=False))


# Figure 3 Supplementary Figure 2
data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/qPCR data/191031_qPCR_results.xlsx')
data = data[(data['Treatment #']==1)|(data['Treatment #']==2)|(data['Treatment #']==6)]
data = data[(data['Primers']=='PDS1')]

fig = sns.FacetGrid(data=data,sharex=False,sharey=True)
fig = fig.map(sns.boxplot,'Guide','Normalized Cp','Effector',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Normalized Cp','Effector',palette='YlOrRd',dodge=True).add_legend()
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/191022_qPCR_results_Viral_levels_of_Effector_versus_no_effector.svg')


data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/qPCR data/191031_qPCR_results.xlsx')
data = data[(data['Treatment #']==1)|(data['Treatment #']==2)|(data['Treatment #']==6)]
data = data[(data['Primers']=='PDS1')]
data = data[(data['Guide']=='On target')]
print(stats.ttest_ind(a=data[data['Effector']=='None']['Normalized Cp'],b=data[data['Effector']=='SRDX']['Normalized Cp'],equal_var=False))

data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/qPCR data/191031_qPCR_results.xlsx')
data = data[(data['Treatment #']==1)|(data['Treatment #']==2)|(data['Treatment #']==6)]
data = data[(data['Primers']=='PDS1')]
data = data[(data['Effector']=='SRDX')]
print(stats.ttest_ind(a=data[data['Guide']=='On target']['Normalized Cp'],b=data[data['Guide']=='Off target']['Normalized Cp'],equal_var=False))

data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/qPCR data/191031_qPCR_results.xlsx')
data = data[(data['Treatment #']==1)|(data['Treatment #']==2)|(data['Treatment #']==6)]
data = data[(data['Primers']=='PDS1')]
data = data[(data['Guide']=='Off target')|(data['Effector']=='None')]
print(stats.ttest_ind(a=data[data['Guide']=='On target']['Normalized Cp'],b=data[data['Guide']=='Off target']['Normalized Cp'],equal_var=False))

# Figure 3 supplementary figure 3
data= pd.read_excel('/Users/clab/Google Drive/Plant viral vectors/Data/201021_ViN_editing_experiment.xlsx')

fig = sns.FacetGrid(data=data,col='Site',sharex=False,sharey=False)
fig = fig.map(sns.boxplot,'FT','Percentage of reads with correct deletion',palette='Greys')
fig = fig.map(sns.swarmplot,'FT','Percentage of reads with correct deletion','Replicate',palette='YlOrRd')
fig.savefig('/Users/clab/Google Drive/Plant viral vectors/Figures/201021_ViN_Editing_experiment.svg')

# Figure 4 B
data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/qPCR data/190829_qPCR_results.xlsx')

data = data[data['Plant']=='Cas9 benthe - 190709']
data = data[data['Primers']!='EF1alpha']
data = data[data['Primers']!='VP64']

fig = sns.FacetGrid(data=data,sharex=False,sharey=True,ylim=(0,0.0035))
fig = fig.map(sns.boxplot,'Guide','Normalized Cp',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Normalized Cp','Replicate',palette='YlOrRd')
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/190829_TRV_DFR_Activation_all_leaves.svg')
print(stats.ttest_ind(a=data[data['Guide']=='Ontarget']['Normalized Cp'],b=data[data['Guide']=='Off target']['Normalized Cp'],equal_var=False))

# Figure 4 D

data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/qPCR data/191014_qPCR_results.xlsx')
data = data[(data['Primers']=='PDS1')]
data = data[(data['Technical replicate']==1)]
fig = sns.FacetGrid(data=data,row='Primers',sharex=False,sharey=False,ylim=(0,0.09))
fig = fig.map(sns.boxplot,'Guide','Normalized Cp',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Normalized Cp','replicate',palette='YlOrRd')
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/191014_qPCR_results_PDS1_Repression_all_leaves_3_weeks.svg')
print(stats.ttest_ind(a=data[data['Guide']=='On target']['Normalized Cp'],b=data[data['Guide']=='Off target']['Normalized Cp'],equal_var=False))

# Figure 4 E
data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/qPCR data/191014_qPCR_results.xlsx')
data = data[(data['Primers']=='PDS2')]
data = data[(data['Technical replicate']==1)]

fig = sns.FacetGrid(data=data,row='Primers',sharex=False,sharey=False,ylim=(0,0.62))
fig = fig.map(sns.boxplot,'Guide','Normalized Cp',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Normalized Cp','replicate',palette='YlOrRd')
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/191014_qPCR_results_PDS2_Repression_all_leaves_3_weeks.svg')

print(stats.ttest_ind(a=data[data['Guide']=='On target']['Normalized Cp'],b=data[data['Guide']=='Off target']['Normalized Cp'],equal_var=False))

# Figure 4 G

data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/qPCR data/191014_qPCR_results.xlsx')
data = data[(data['Primers']=='PDS2')]
data = data[(data['Site']=='2 above infiltrated leaf')]
fig = sns.FacetGrid(data=data,row='Site',sharex=False,sharey=False,ylim=(0,0.7))
fig = fig.map(sns.boxplot,'Guide','Normalized Cp',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Normalized Cp','replicate',palette='YlOrRd')
print(stats.ttest_ind(a=data[data['Guide']=='On target']['Normalized Cp'],b=data[data['Guide']=='Off target']['Normalized Cp'],equal_var=False))
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/191017_Benthe_ViN_PDS_multiple_leaf_repression_characterization_box_plot_2_leaves_above.svg')

# Figure 4 H
data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/qPCR data/191018_qPCR_results.xlsx')
data = data[(data['Site']=='2 above infiltrated leaf')]
data = data[(data['Primers']=='PDS1')]

fig = sns.FacetGrid(data=data,row='Primers',sharex=False,sharey=False)
fig = fig.map(sns.boxplot,'Guide','Normalized Cp',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Normalized Cp','replicate',palette='YlOrRd')
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/191019_Benthe_ViN_PDS_4_week_for_sustained_repression_boxplot.svg')

print(stats.ttest_ind(a=data[data['Guide']=='On target']['Normalized Cp'],b=data[data['Guide']=='Off target']['Normalized Cp'],equal_var=False))

# Figure 4 Supplementary Figure 1 B
data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/qPCR data/191011_qPCR_results.xlsx')
data1=data[data['Primers']=='PCP']
data1['Week'] = ['2 weeks']*len(data1['Primers']) 

data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/qPCR data/191014_qPCR_results.xlsx')
data2=data[data['Primers']=='PCP']
data2['Week'] = ['3 weeks']*len(data2['Primers']) 


data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/qPCR data/191018_qPCR_results.xlsx')
data3=data[data['Primers']=='PCP']
data3['Week'] = ['4 weeks']*len(data3['Primers']) 

data=data1.append(data2).append(data3)

data=data[(data['Site']=='Infiltrated leaf outside infiltration zone')|(data['Site']=='2 above infiltrated leaf')|(data['Site']=='4 leaves above infiltrated leaf')]
data=data[data['Normalized Cp']>0.1]
data=data[data['Normalized Cp']<2000]

fig = sns.FacetGrid(data=data,col='Week',sharex=False,sharey=True)
fig = fig.map(sns.boxplot,'Site','Normalized Cp',palette='Spectral')
fig = fig.map(sns.swarmplot,'Site','Normalized Cp','replicate',palette='Greys').add_legend()
fig.fig.get_axes()[0].set_yscale('log')

fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/191018_qPCR_results_benthe_TRV_movement_2-4weeks_only_some_leaves.svg')

# Figure 4 Supplementary Figure 2 B

data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/qPCR data/191014_qPCR_results.xlsx')
data = data[(data['Primers']=='PDS1')]
data = data[(data['Technical replicate']==1)]

fig = sns.FacetGrid(data=data,sharex=False,sharey=False,aspect=2)
fig = fig.map(sns.boxplot,'Site','Normalized Cp','Guide',palette='Greys').add_legend()
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/191014_qPCR_results_PDS1_Repression_across_leaves_3_weeks.svg')


# Figure 5 C
data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/qPCR data/200212.1_qPCR_results.xlsx')

data=data[data['Primers']=='Procera']
data=data[data['Site']=='3rd systemic tri foliar']
fig = sns.FacetGrid(data=data,sharex=False,sharey=False)
fig = fig.map(sns.boxplot,'Guide','Normalized Cp',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Normalized Cp','Replicate',palette='YlOrRd')
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/200212.1_ViN2_Procera_repression_boxplot.svg')

print(stats.ttest_ind(a=data[data['Guide']=='On target']['Normalized Cp'],b=data[data['Guide']=='Off target']['Normalized Cp'],equal_var=False))

# Figure 5 D
data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/Data/200309_ViN_Procera_Cas9_M82_Phenotyping_50Dpi_internode_lengths.xlsx')

data=data[data['Internode Number']<7]
data=data[data['Internode Number']>1]


fig = sns.FacetGrid(data=data,sharex=False,sharey=False,aspect=1.5)
fig = fig.map(sns.boxplot,'Internode Number','Internode length','Guide',palette='Greys')
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/200309_ViN_Procera_Cas9_M82_Phenotyping_50Dpi_all_internodes.svg')


# Figure 5 E
data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/Data/200309_ViN_Procera_Cas9_M82_Phenotyping_50Dpi_internode_lengths.xlsx')
data2=data2[data2['Internode Number']<6]
data2=data2[data2['Internode Number']>3]


fig = sns.FacetGrid(data=data2,sharex=False,sharey=False,ylim=(0,3.5))
fig = fig.map(sns.boxplot,'Guide','Internode length',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Internode length','Replicate',palette='YlOrRd')
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/200309_ViN_Procera_Cas9_M82_Phenotyping_50Dpi_internode_4_5_lengths.svg')

data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/Data/200309_ViN_Procera_Cas9_M82_Phenotyping_50Dpi.xlsx')
print('Internodes (4-5):')
print(stats.ttest_ind(a=data2[data2['Guide']=='On target']['Internode length'],b=data2[data2['Guide']=='Off target']['Internode length'],equal_var=False))

# Figure 5 F
data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/Data/200310_ViN_Procera_Cas9_M82_Phenotyping_51Dpi_leaf_lengths.xlsx')
data=data[data['Branch number']==8]
data=data[data['Leaf length (cm)']!=0]

fig = sns.FacetGrid(data=data,sharex=False,sharey=False,ylim=(0,10))
fig = fig.map(sns.boxplot,'Guide','Leaf length (cm)',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Leaf length (cm)','Leaf number',palette='YlOrRd').add_legend()
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/200310_ViN_Procera_Cas9_M82_Phenotyping_51Dpi_leaf_8_lengths.svg')
print('Branch 8')
print(stats.ttest_ind(a=data[data['Guide']=='On target']['Leaf length (cm)'],b=data[data['Guide']=='Off target']['Leaf length (cm)'],equal_var=False))

# Figure 5 Supplementary Figure 1 B
data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/qPCR data/200212.1_qPCR_results.xlsx')

data=data[data['Primers']=='PCP']
data=data[data['Guide']=='On target']

fig = sns.FacetGrid(data=data,sharex=False,sharey=True,aspect=2)
fig = fig.map(sns.boxplot,'Site','Normalized Cp',palette='Spectral')
fig = fig.map(sns.swarmplot,'Site','Normalized Cp',palette='Greys')
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/200212.1_qPCR_results_tomato_TRV_movement_5weeks.svg')

# Figure 5 Supplementary Figure 2 B
data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/Data/200309_ViN_Procera_Cas9_M82_Phenotyping_First_trial_final_measurement_internode_lengths.xlsx')

data2=data[data['Internode Number']==4]
fig = sns.FacetGrid(data=data2,sharex=False,sharey=False,ylim=(0,3.6),aspect=.9)
fig = fig.map(sns.boxplot,'Guide','Internode length (inches)',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Internode length (inches)','Replicate',palette='YlOrRd').add_legend()
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/200309_ViN_Procera_Cas9_M82_Phenotyping_First_trial_final_measurement_internode_4_lengths.svg')

data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/Data/200309_ViN_Procera_Cas9_M82_Phenotyping_First_trial_final_measurement_internode_lengths.xlsx')
print('Internodes (4):')
print(stats.ttest_ind(a=data2[data2['Guide']=='On target']['Internode length (inches)'],b=data2[data2['Guide']=='Off target']['Internode length (inches)'],equal_var=False))

# Figure 5 Supplementary Figure 2 C
data = pd.io.excel.read_excel('/Users/arjun/Google Drive/Plant viral vectors/Data/200105_M82Cas9_TRV_ViN2_Procera_leaf_size_phenotyping_data_all_together.xlsx')

fig = sns.FacetGrid(data=data,sharex=False,sharey=False,ylim=(0,110000))
fig = fig.map(sns.boxplot,'Guide','Leaf Area',palette='Greys')
fig = fig.map(sns.swarmplot,'Guide','Leaf Area','Replicate',palette='YlOrRd')
fig.savefig('/Users/arjun/Google Drive/Plant viral vectors/Figures/200105_M82Cas9_TRV_ViN2_Procera_leaf_size_phenotyping.svg')

print(stats.ttest_ind(a=data[data['Guide']=='On target']['Leaf Area'],b=data[data['Guide']=='Off target']['Leaf Area'],equal_var=False))
